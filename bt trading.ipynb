# %%
import bt
import matplotlib.pyplot as plt

# %%
bt_data=bt.get('goog, amzn, tsla',start ='2023-04-01', end ='2024-04-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
#define strategy 
bt_strategy=bt.Strategy('Trade Weekly',
                        [bt.algos.RunWeekly(), #run weekly
                         bt.algos.SelectAll(), #use all data
                         bt.algos.WeighEqually(), #Maintain Equal Weights
                         bt.algos.Rebalance()]) #rebalance

# %%
#backtest
bt_test=bt.Backtest(bt_strategy,bt_data)

# %%
bt_res=bt.run(bt_test)

# %%
bt_res.plot(title="backtest result")
# Out:
# <Axes: title={'center': 'backtest result'}>

# %%
#get transcations
bt_res.get_transactions()
# Out:
#                           price  quantity
# Date       Security
# 2023-04-03 amzn      102.410004    3254.0
#            goog      104.910004    3177.0
#            tsla      194.770004    1711.0
# 2023-04-10 amzn      102.169998     -31.0
#            goog      106.949997     -98.0
# ...                         ...       ...
# 2024-03-18 goog      148.479996    -142.0
#            tsla      173.800003     107.0
# 2024-03-25 amzn      179.710007     -41.0
#            goog      151.149994     -12.0
#            tsla      172.630005      52.0
#
# [155 rows x 2 columns]

# %%
resInfo=bt_res.stats

# %%
max_drawdown=resInfo.loc['max_drawdown']

# %%
print('Maximum drawdown: %.2f' % max_drawdown)
# Out:
# Maximum drawdown: -0.18
# C:\Users\Clari\AppData\Local\Temp\ipykernel_29784\3200643811.py:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('Maximum drawdown: %.2f' % max_drawdown)

# %%
avg_drawdown=resInfo.loc['avg_drawdown']

# %%
print('average drawdown: %.2f' % avg_drawdown)
# Out:
# average drawdown: -0.04
# C:\Users\Clari\AppData\Local\Temp\ipykernel_29784\3532654609.py:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('average drawdown: %.2f' % avg_drawdown)

# %%
avg_drawdown_days=resInfo.loc['avg_drawdown_days']

# %%
print('average drawdown days: %.0f' % avg_drawdown_days)
# Out:
# average drawdown days: 20
# C:\Users\Clari\AppData\Local\Temp\ipykernel_29784\2905965883.py:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('average drawdown days: %.0f' % avg_drawdown_days)

# %%
cagr=resInfo.loc['cagr']

# %%
calmar_calc=cagr/max_drawdown*(-1)

# %%
print('Calmar Ratio calculated: %.2f'% calmar_calc)
# Out:
# Calmar Ratio calculated: 2.06
# C:\Users\Clari\AppData\Local\Temp\ipykernel_29784\3946520330.py:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('Calmar Ratio calculated: %.2f'% calmar_calc)
